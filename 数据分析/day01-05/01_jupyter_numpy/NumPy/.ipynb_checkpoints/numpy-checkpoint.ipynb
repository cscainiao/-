# %% [markdown]
# # NumPy get started

# %% [markdown]
# 导入numpy库，并查看numpy版本

# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.14.5'

# %%
# 其实NumPy里面没别的 就是ndarray n多 d dimension 维度 数组 多维数组

# %%
ndarr1 = np.random.randint(1,5,3)
ndarr1
list1 = [1,2,3]
list1
print(ndarr1,list1) #  看上去一样 其实是两个东西 只不过ndarr1重写了__str__()
# Out:
# [3 3 2] [1, 2, 3]

# %%
print(type(ndarr1),type(list1))
# Out:
# <class 'numpy.ndarray'> <class 'list'>

# %% [markdown]
# ## 一、创建ndarray

# %% [markdown]
# ### 1. 使用np.array()创建多维数组

# %% [markdown]
# 参数为列表：
# np.array([1,2,3])

# %% [markdown]
# 注意：
# - numpy默认ndarray的所有元素的类型是相同的
# - 如果传进来的列表中包含不同的类型，则统一为同一类型，优先级：str>float>int

# %% [markdown]
# ### 2. 使用np的常用函数(routines)创建

# %% [markdown]
# 包含以下常见创建方法：
#
# 1) np.ones(shape, dtype=None, order='C')

# %% [markdown]
# 2) np.zeros(shape, dtype=float, order='C')

# %% [markdown]
# 3) np.full(shape, fill_value, dtype=None, order='C')

# %% [markdown]
# 4) np.eye(N, M=None, k=0, dtype=float)
# 对角线为1其他的位置为0

# %% [markdown]
# 5)
#
# np.linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None)
#
# np.logspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None)

# %% [markdown]
# 6) np.arange([start, ]stop, [step, ]dtype=None)

# %% [markdown]
# 7) np.random.randint(low, high=None, size=None, dtype='l')

# %% [markdown]
# 8) np.random.randn(d0, d1, ..., dn)
#
# 标准正太分布

# %% [markdown]
# 9)np.random.normal(loc=0.0, scale=1.0, size=None)

# %% [markdown]
# 10) np.random.random(size=None)
#
# 生成0到1的随机数，左闭右开

# %% [markdown]
# ### 练习：使用随机数成成一张图片

# %%
# 图片是什么？？？
# 其实图片就是一个ndarray，多维的数组
import matplotlib.pyplot as plt
jin = plt.imread('./jin.png')
jin
# Out:
# array([[[0.24313726, 0.24313726, 0.24705882],
#         [0.22745098, 0.23137255, 0.2509804 ],
#         [0.38039216, 0.3882353 , 0.42352942],
#         ...,
#         [0.34509805, 0.36078432, 0.3764706 ],
#         [0.12941177, 0.12941177, 0.13333334],
#         [0.7411765 , 0.7411765 , 0.7411765 ]],
#
#        [[0.14117648, 0.14509805, 0.14901961],
#         [0.47843137, 0.49019608, 0.53333336],
#         [0.87058824, 0.8901961 , 0.96862745],
#         ...,
#         [0.8117647 , 0.84705883, 0.8784314 ],
#         [0.2901961 , 0.29411766, 0.29803923],
#         [0.77254903, 0.77254903, 0.77254903]],
#
#        [[0.3529412 , 0.35686275, 0.3647059 ],
#         [0.5176471 , 0.5294118 , 0.5764706 ],
#         [0.88235295, 0.9019608 , 0.9764706 ],
#         ...,
#         [0.827451  , 0.8627451 , 0.89411765],
#         [0.29803923, 0.3019608 , 0.30588236],
#         [0.7764706 , 0.7764706 , 0.7764706 ]],
#
#        ...,
#
#        [[0.33333334, 0.34509805, 0.35686275],
# ...

# %%
print(type(jin))
# Out:
# <class 'numpy.ndarray'>

# %%
jin.shape
# Out:
# (273, 411, 3)

# %%
random_pic = np.random.random(size = (273,411,3))
random_pic.shape
random_pic
# Out:
# array([[[8.00274462e-01, 3.04898470e-01, 6.38073123e-01],
#         [2.59140857e-01, 8.46655310e-02, 6.35159523e-01],
#         [3.05387828e-01, 1.45508848e-01, 8.62965506e-01],
#         ...,
#         [7.36755857e-01, 1.91073074e-01, 8.44755084e-01],
#         [8.36838140e-01, 1.36200254e-01, 7.45203749e-01],
#         [1.31396988e-01, 1.02181424e-01, 6.38429076e-01]],
#
#        [[2.07397999e-01, 2.01785033e-01, 3.69727312e-01],
#         [3.48781485e-02, 4.03692069e-01, 3.10095089e-01],
#         [1.77814521e-01, 9.76000746e-01, 8.07922270e-01],
#         ...,
#         [8.91179563e-01, 4.26964750e-01, 6.76768056e-01],
#         [6.96751833e-01, 4.95957277e-01, 7.85366144e-01],
#         [2.77915488e-01, 5.69033543e-01, 9.92164700e-01]],
#
#        [[7.32196568e-02, 4.50248017e-01, 7.86233428e-01],
#         [3.28474972e-01, 4.71255974e-01, 1.19068322e-01],
#         [4.17537810e-01, 2.32833703e-01, 7.90104215e-01],
#         ...,
# ...

# %%
# 显示一个图片
plt.imshow(jin,cmap = 'gray')

# %%
plt.imshow(random_pic)

# %% [markdown]
# ## 二、ndarray的属性

# %% [markdown]
# 4个必记参数：
# ndim：维度
# shape：形状（各维度的长度）
# size：总长度
#
# dtype：元素类型

# %% [markdown]
# ## 三、ndarray的基本操作

# %% [markdown]
# ### 1. 索引
# 一维与列表完全一致
# 多维时同理

# %% [markdown]
# 根据索引修改数据

# %% [markdown]
# ### 2. 切片
# 一维与列表完全一致
# 多维时同理

# %% [markdown]
# 将数据反转，例如[1,2,3]---->[3,2,1]

# %% [markdown]
# 两个::进行切片

# %% [markdown]
# ### 3. 变形
# 使用reshape函数，注意参数是一个tuple！

# %% [markdown]
# ### 4. 级联
# 1. np.concatenate()
# 级联需要注意的点：
# - 级联的参数是列表：一定要加中括号或小括号
# - 维度必须相同
# - 形状相符
# - 【重点】级联的方向默认是shape这个tuple的第一个值所代表的维度方向
# - 可通过axis参数改变级联的方向

# %% [markdown]
# 2. np.hstack与np.vstack
# 水平级联与垂直级联,处理自己，进行维度的变更

# %% [markdown]
# ### 5. 切分

# %% [markdown]
# 与级联类似，三个函数完成切分工作：
# - np.split
# - np.vsplit
# - np.hsplit

# %% [markdown]
# ### 6. 副本
# 所有赋值运算不会为ndarray的任何元素创建副本。对赋值后的对象的操作也对原来的对象生效。

# %% [markdown]
# 可使用copy()函数创建副本

# %% [markdown]
# ## 四、ndarray的聚合操作

# %% [markdown]
# ### 1. 求和np.sum

# %% [markdown]
# ### 2. 最大最小值：np.max/ np.min
# 同理

# %% [markdown]
# ### 3. 其他聚合操作
#     Function Name	NaN-safe Version	Description
#     np.sum	np.nansum	Compute sum of elements
#     np.prod	np.nanprod	Compute product of elements
#     np.mean	np.nanmean	Compute mean of elements
#     np.std	np.nanstd	Compute standard deviation
#     np.var	np.nanvar	Compute variance
#     np.min	np.nanmin	Find minimum value
#     np.max	np.nanmax	Find maximum value
#     np.argmin	np.nanargmin	Find index of minimum value
#     np.argmax	np.nanargmax	Find index of maximum value
#     np.median	np.nanmedian	Compute median of elements
#     np.percentile	np.nanpercentile	Compute rank-based statistics of elements
#     np.any	N/A	Evaluate whether any elements are true
#     np.all	N/A	Evaluate whether all elements are true
#     np.power 幂运算

# %% [markdown]
# np.sum 和 np.nansum 的区别
# nan not a number

# %% [markdown]
# #### 操作文件
#
# 使用pandas打开文件president_heights.csv
# 获取文件中的数据

# %% [markdown]
# ## 五、ndarray的矩阵操作

# %% [markdown]
# ### 1. 基本矩阵操作

# %% [markdown]
# 1) 算术运算符：
# - 加减乘除

# %% [markdown]
# 2) 矩阵积np.dot()

# %% [markdown]
# ### 2. 广播机制

# %% [markdown]
# 【重要】ndarray广播机制的两条规则
# - 规则一：为缺失的维度补1
# - 规则二：假定缺失元素用已有值填充
#
#
# 例1：
# m = np.ones((2, 3))
# a = np.arange(3)
# 求M+a

# %% [markdown]
# 例2：
# a = np.arange(3).reshape((3, 1))
# b = np.arange(3)
# 求a+b

# %% [markdown]
# 习题
# a = np.ones((4, 1))
# b = np.arange(4)
# 求a+b

# %% [markdown]
# ## 六、ndarray的排序

# %% [markdown]
# 小测验：
# 使用以上所学numpy的知识，对一个ndarray对象进行选择排序。
#
# def Sortn(x):
#
# 代码越短越好

# %% [markdown]
# ### 1. 快速排序
# np.sort()与ndarray.sort()都可以，但有区别：
# - np.sort()不改变输入
# - ndarray.sort()本地处理，不占用空间，但改变输入

# %% [markdown]
# ### 2. 部分排序
# np.partition(a,k)
#
# 有的时候我们不是对全部数据感兴趣，我们可能只对最小或最大的一部分感兴趣。
# - 当k为正时，我们想要得到最小的k个数
# - 当k为负时，我们想要得到最大的k个数
