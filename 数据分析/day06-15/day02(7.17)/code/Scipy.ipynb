# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# scipy求解积分
from scipy.integrate import quad

# 绘图专用的工具
import matplotlib.pyplot as plt

# 表示把matplotlib生成的图像绘制到当前notebook当中
# %matplotlib inline

# %% [markdown]
# # 求积分

# %%
# 确认不规则图形的函数曲线
f = lambda x:(1-x**2)**0.5
# 确认不规则图形x轴的界限（-1，1）
b = 1
a = -1

# %%
x = np.linspace(-1,1,100)
y = f(x)

# 绘制线性图
plt.plot(x,y)
plt.plot(x,-y)
# 调整坐标轴刻度的比例一致
plt.axis('equal')
# Out:
# (-1.1, 1.1, -1.0999438818457405, 1.0999438818457405)

# %%
half_area,error = quad(f,a,b)
2*half_area/1
# Out:
# 3.1415926535897967

# %%
# 绘制正弦曲线
x1 = np.linspace(0,2*np.pi,100)
y1 = np.sin(x1)
plt.plot(x1,y1)

# %% [markdown]
# # 文件输入输出

# %%
# 处理文本输入
import scipy.io as io
# 处理图片输入输出
import scipy.misc as misc

# %%
# 把数据存储为2进制格式的数据
io.savemat()
# 读取二进制的数据文件
io.loadmat()

# %%
# 数据写入
# 支持数组对象
xiaoming = np.random.randint(0,100,size=3)
index = np.array(['语文','数学','英语'])

mdic = {
    'xiaomingkey':xiaoming,
    'indexkey':index
}
# 不需要制定文件后缀，只保存为mat格式
io.savemat('xiaomingpath',mdict=mdic)

# %%
# 读取二进制文件
xiaoming = io.loadmat('xiaomingpath.mat')

# %%
display(xiaoming['xiaomingkey'],xiaoming['indexkey'])
# Out:
# array([[69, 13, 37]])
# array(['语文', '数学', '英语'], dtype='<U2')

# %%
# 【注意】 misc所有的功能都已经被其他类库替代
# 图片读取
misc.imread()
# 图片保存
misc.imsave()
# 添加滤镜效果
misc.imfilter()
# 调整图片大小
misc.imresize()
# 调整图片旋转角度
misc.imrotate()
# 图片展示
misc.imshow()
# Out:
# d:\python3.6\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-ee7228e8e64c> in <module>()
#       1 #
# ----> 2 misc.imread()
#       3 misc.imsave()
#
# d:\python3.6\lib\site-packages\numpy\lib\utils.py in newfunc(*args, **kwds)
#      99             """`arrayrange` is deprecated, use `arange` instead!"""
#     100             warnings.warn(depdoc, DeprecationWarning, stacklevel=2)
# --> 101             return func(*args, **kwds)
#     102
#     103         newfunc = _set_function_name(newfunc, old_name)
#
# TypeError: imread() missing 1 required positional argument: 'name'

# %%
plt.imshow(misc.imread('meixi.jpg'))
# Out:
# d:\python3.6\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
# 使用imageio.imread替代misc.imread()
from imageio import imread

plt.imshow(imread('meixi.jpg'))

# %%
meixi = plt.imread('meixi.jpg')

# %%
meixi.shape
# Out:
# (525, 700, 3)

# %%
plt.imshow(meixi.max(axis=2),cmap='gray')
gray_meixi = meixi.max(axis=2)

# %%
from imageio import imwrite
imwrite('gray_meixi2.jpg',gray_meixi)

# %%
# 'blur', 'contour', 'detail', 'edge_enhance', 'edge_enhance_more', 
# 'emboss', 'find_edges', 'smooth', 'smooth_more', 'sharpen'
# 滤镜效果的新函数，自己查询
plt.imshow(misc.imfilter(meixi,'contour'))
# Out:
# d:\python3.6\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `imfilter` is deprecated!
# `imfilter` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use Pillow filtering functionality directly.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# 使用0-100之间的数，设置原始图像的百分比
# plt.imshow(misc.imresize(meixi,50))
# 使用0-1之间的小数，设置原始图像的比例
# plt.imshow(misc.imresize(meixi,0.5))
# 分别制定（heigth,width）的尺寸来修该原始图片大小
plt.imshow(misc.imresize(meixi,(200,300)))
# Out:
# d:\python3.6\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# scikit learning
from skimage.transform import resize
# 使用skimage处理图片的大小
plt.imshow(resize(meixi,output_shape=(300,400),mode='reflect'))

# %%
# misc.imrotate不会改变原始图片的形状
plt.imshow(misc.imrotate(meixi,90,interp='bilinear'))
# Out:
# C:\Users\ALIENWARE\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `imrotate` is deprecated!
# `imrotate` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.rotate`` instead.

# %%
from skimage.transform import rotate
# mode 是设置空白处的填充方式 'constant', 'edge', 'symmetric', 'reflect', 'wrap'
plt.imshow(rotate(meixi,angle=90,mode='reflect'))
